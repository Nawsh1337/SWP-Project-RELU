# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class ReLU_MaxNN2(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(ReLU_MaxNN2, self).__init__()
        self.hidden = nn.Linear(input_size, hidden_size)
        self.output = nn.Linear(hidden_size, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        hidden_out = self.relu(self.hidden(x))
        output = self.output(hidden_out)

        return self.relu(output)
#MODEL CLASS DOES NOT HAVE RLU ON OUTPUT

# %%
from sklearn.model_selection import train_test_split

learning_rate = 0.001
epochs = 5000
num_samples = 100000

results = []

input_sizes = [3]
hidden_sizes = [x+1 for x in range(10)]

for input_size in input_sizes:
    for hidden_size in hidden_sizes:

        X = torch.rand(num_samples, input_size) * 20 - 10  #Random inputs between -10 and 10
        Y = torch.max(X, dim=1, keepdim=True)[0]  #True max

        #DATA IS TRUE VALUE
        #Split into training and testing data
        X_train, X_test, Y_train, Y_test = train_test_split(
            X.numpy(), Y.numpy(), test_size=0.2, random_state=42
        )
        X_train, X_test = torch.tensor(X_train), torch.tensor(X_test)
        Y_train, Y_test = torch.tensor(Y_train), torch.tensor(Y_test)

        model = ReLU_MaxNN2(input_size, hidden_size)
        criterion = nn.MSELoss()  #Mean Squared Error loss
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        for epoch in range(epochs):
            optimizer.zero_grad()
            outputs = model(X_train)
            loss = criterion(outputs, Y_train)
            loss.backward()
            optimizer.step()

        with torch.no_grad():
            test_outputs = model(X_test)
            test_loss = criterion(test_outputs, Y_test).item()

        results.append({
            'input_size': input_size,
            'hidden_size': hidden_size,
            'training_loss': loss.item(),
            'testing_loss': test_loss
        })

# %%
import pandas as pd

results_df = pd.DataFrame(results)

results_df.to_csv("model_training_prediction_max.csv", index=False)
print("Results saved to model_training_prediction_max.csv")

print(results_df)
# Out:
# Results saved to model_training_prediction_max.csv
#    input_size  hidden_size  training_loss  testing_loss
# 0           3            1       6.342737      6.273100
# 1           3            2       5.841757      5.731822
# 2           3            3       4.165321      4.115490
# 3           3            4       2.014081      1.991451
# 4           3            5       1.681725      1.651089
# 5           3            6       1.541345      1.537566
# 6           3            7       1.462627      1.400525
# 7           3            8       1.535508      1.573211
# 8           3            9       1.469277      1.466099
# 9           3           10       1.443400      1.412649

# %%
df = pd.read_csv("model_training_prediction_max.csv")

min_loss = df["testing_loss"].min()

epsilon = 0.05  #Allowable margin for loss

filtered_df = df[df["testing_loss"] <= min_loss + epsilon]

best_model = filtered_df.sort_values(by="hidden_size").iloc[0]

print("Best Model:")
print(best_model)
# Out:
# Best Model:
# input_size       3.000000
# hidden_size      7.000000
# training_loss    1.462627
# testing_loss     1.400525
# Name: 6, dtype: float64

# %%
import matplotlib.pyplot as plt

best_model_info = filtered_df.sort_values(by="hidden_size").iloc[0]
best_hidden_size = int(best_model_info['hidden_size'])
print(f"Best model has {best_hidden_size} hidden units with testing loss {best_model_info['testing_loss']:.4f}")

torch.manual_seed(42)
test_samples = torch.rand(20000, 3) * 20 - 10
test_labels = torch.max(test_samples, dim=1, keepdim=True)[0]

input_size = 3
best_model = ReLU_MaxNN2(input_size, best_hidden_size)
optimizer = optim.Adam(best_model.parameters(), lr=learning_rate)

train_losses = []
test_losses = []

for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = best_model(X)
    loss = criterion(outputs, Y)
    loss.backward()
    optimizer.step()
    train_losses.append(loss.item())

    with torch.no_grad():
        test_outputs = best_model(test_samples)
        test_loss = criterion(test_outputs, test_labels).item()
        test_losses.append(test_loss)

    if (epoch + 1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {loss.item():.4f}, Test Loss: {test_loss:.4f}')

with torch.no_grad():
    predictions = best_model(test_samples)

print("\nTest Results:")
for i in range(100):
    sample = test_samples[i].numpy().round(2)
    true_avg = test_labels[i].item()
    pred = predictions[i].item()
    print(f"Sample {i+1}: {sample} | True: {true_avg:.2f} | Pred: {pred:.2f}")

mae = torch.mean(torch.abs(predictions - test_labels)).item()
print(f"\nMean Absolute Error: {mae:.4f}")

plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss')
plt.plot(range(epochs), test_losses, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Losses Over Epochs for Max Model')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Best model has 7 hidden units with testing loss 1.4005
# Epoch [100/5000], Train Loss: 26.7492, Test Loss: 26.8198
# Epoch [200/5000], Train Loss: 14.5621, Test Loss: 14.5526
# Epoch [300/5000], Train Loss: 7.6619, Test Loss: 7.6226
# Epoch [400/5000], Train Loss: 4.6380, Test Loss: 4.6002
# Epoch [500/5000], Train Loss: 3.2992, Test Loss: 3.2911
# Epoch [600/5000], Train Loss: 2.7310, Test Loss: 2.7331
# Epoch [700/5000], Train Loss: 2.4412, Test Loss: 2.4491
# Epoch [800/5000], Train Loss: 2.3016, Test Loss: 2.3127
# Epoch [900/5000], Train Loss: 2.2342, Test Loss: 2.2461
# Epoch [1000/5000], Train Loss: 2.1951, Test Loss: 2.2071
# Epoch [1100/5000], Train Loss: 2.1669, Test Loss: 2.1790
# Epoch [1200/5000], Train Loss: 2.1435, Test Loss: 2.1558
# Epoch [1300/5000], Train Loss: 2.1229, Test Loss: 2.1354
# Epoch [1400/5000], Train Loss: 2.1044, Test Loss: 2.1171
# Epoch [1500/5000], Train Loss: 2.0877, Test Loss: 2.1006
# Epoch [1600/5000], Train Loss: 2.0723, Test Loss: 2.0855
# Epoch [1700/5000], Train Loss: 2.0581, Test Loss: 2.0715
# Epoch [1800/5000], Train Loss: 2.0449, Test Loss: 2.0585
# Epoch [1900/5000], Train Loss: 2.0324, Test Loss: 2.0463
# Epoch [2000/5000], Train Loss: 2.0204, Test Loss: 2.0346
# Epoch [2100/5000], Train Loss: 2.0089, Test Loss: 2.0234
# Epoch [2200/5000], Train Loss: 1.9979, Test Loss: 2.0126
# Epoch [2300/5000], Train Loss: 1.9871, Test Loss: 2.0021
# Epoch [2400/5000], Train Loss: 1.9765, Test Loss: 1.9918
# Epoch [2500/5000], Train Loss: 1.9661, Test Loss: 1.9817
# Epoch [2600/5000], Train Loss: 1.9558, Test Loss: 1.9717
# Epoch [2700/5000], Train Loss: 1.9456, Test Loss: 1.9617
# Epoch [2800/5000], Train Loss: 1.9353, Test Loss: 1.9517
# Epoch [2900/5000], Train Loss: 1.9252, Test Loss: 1.9418
# Epoch [3000/5000], Train Loss: 1.9150, Test Loss: 1.9319
# Epoch [3100/5000], Train Loss: 1.9048, Test Loss: 1.9219
# Epoch [3200/5000], Train Loss: 1.8945, Test Loss: 1.9118
# Epoch [3300/5000], Train Loss: 1.8840, Test Loss: 1.9016
# Epoch [3400/5000], Train Loss: 1.8734, Test Loss: 1.8911
# Epoch [3500/5000], Train Loss: 1.8624, Test Loss: 1.8804
# Epoch [3600/5000], Train Loss: 1.8509, Test Loss: 1.8693
# Epoch [3700/5000], Train Loss: 1.8390, Test Loss: 1.8578
# Epoch [3800/5000], Train Loss: 1.8266, Test Loss: 1.8458
# Epoch [3900/5000], Train Loss: 1.8134, Test Loss: 1.8331
# Epoch [4000/5000], Train Loss: 1.7995, Test Loss: 1.8192
# Epoch [4100/5000], Train Loss: 1.7848, Test Loss: 1.8044
# Epoch [4200/5000], Train Loss: 1.7692, Test Loss: 1.7889
# Epoch [4300/5000], Train Loss: 1.7536, Test Loss: 1.7730
# Epoch [4400/5000], Train Loss: 1.7380, Test Loss: 1.7567
# Epoch [4500/5000], Train Loss: 1.7221, Test Loss: 1.7404
# Epoch [4600/5000], Train Loss: 1.7058, Test Loss: 1.7238
# Epoch [4700/5000], Train Loss: 1.6884, Test Loss: 1.7061
# Epoch [4800/5000], Train Loss: 1.6687, Test Loss: 1.6866
# Epoch [4900/5000], Train Loss: 1.6456, Test Loss: 1.6638
# Epoch [5000/5000], Train Loss: 1.6253, Test Loss: 1.6442
#
# Test Results:
# Sample 1: [ 7.65  8.3  -2.34] | True: 8.30 | Pred: 9.05
# Sample 2: [ 9.19 -2.19  2.02] | True: 9.19 | Pred: 8.40
# Sample 3: [-4.87  5.87  8.82] | True: 8.82 | Pred: 8.59
# Sample 4: [-7.34  8.69  1.87] | True: 8.69 | Pred: 8.55
# Sample 5: [7.39 1.35 4.82] | True: 7.39 | Pred: 7.49
# Sample 6: [-1.41  7.71  1.48] | True: 7.71 | Pred: 7.11
# Sample 7: [-4.67  2.55 -4.61] | True: 2.55 | Pred: 2.15
# Sample 8: [-1.17 -4.06  6.63] | True: 6.63 | Pred: 6.82
# Sample 9: [-7.89 -4.61 -2.82] | True: -2.82 | Pred: 0.00
# Sample 10: [-6.01  0.94 -9.88] | True: 0.94 | Pred: 1.18
# Sample 11: [ 9.03 -8.49  7.72] | True: 9.03 | Pred: 9.98
# Sample 12: [ 1.66 -3.25  6.18] | True: 6.18 | Pred: 6.54
# Sample 13: [1.56 8.08 1.09] | True: 8.08 | Pred: 7.37
# Sample 14: [-3.15  2.69 -2.71] | True: 2.69 | Pred: 2.16
# Sample 15: [4.21 8.93 5.78] | True: 8.93 | Pred: 7.90
# Sample 16: [-4.37  5.77  1.79] | True: 5.77 | Pred: 6.10
# Sample 17: [ 5.08 -6.1  -9.9 ] | True: 5.08 | Pred: 5.20
# Sample 18: [-3.86 -7.67  8.21] | True: 8.21 | Pred: 7.63
# Sample 19: [2.88 4.14 3.16] | True: 4.14 | Pred: 5.31
# Sample 20: [-0.17  7.83 -7.11] | True: 7.83 | Pred: 7.68
# Sample 21: [ 0.63 -6.83  3.08] | True: 3.08 | Pred: 3.41
# Sample 22: [-3.44  3.06 -2.08] | True: 3.06 | Pred: 2.49
# Sample 23: [ 8.29 -5.93 -5.96] | True: 8.29 | Pred: 7.82
# Sample 24: [-5.96  8.99  3.33] | True: 8.99 | Pred: 8.80
# Sample 25: [ 9.62 -8.25 -9.92] | True: 9.62 | Pred: 9.36
# Sample 26: [-7.82 -6.73  4.05] | True: 4.05 | Pred: 3.80
# Sample 27: [ 3.58  8.31 -5.16] | True: 8.31 | Pred: 8.19
# Sample 28: [-6.82  5.31 -4.04] | True: 5.31 | Pred: 4.86
# Sample 29: [ 6.07 -2.37  5.72] | True: 6.07 | Pred: 6.60
# Sample 30: [-7.77 -5.05  3.05] | True: 3.05 | Pred: 2.84
# Sample 31: [ 2.11 -2.55  5.96] | True: 5.96 | Pred: 6.46
# Sample 32: [ 6.8  -7.25 -5.34] | True: 6.80 | Pred: 6.43
# Sample 33: [ 9.16 -3.37 -3.55] | True: 9.16 | Pred: 8.38
# Sample 34: [-9.68 -5.73  2.5 ] | True: 2.50 | Pred: 2.31
# Sample 35: [-1.32 -7.26  0.23] | True: 0.23 | Pred: 0.94
# Sample 36: [-6.83 -8.48 -5.51] | True: -5.51 | Pred: 0.00
# Sample 37: [-8.75 -6.37 10.  ] | True: 10.00 | Pred: 9.43
# Sample 38: [ 1.89  3.08 -9.33] | True: 3.08 | Pred: 4.60
# Sample 39: [-6.57 -3.33  1.56] | True: 1.56 | Pred: 1.50
# Sample 40: [-8.8  -4.31 -5.99] | True: -4.31 | Pred: 0.00
# Sample 41: [ 0.03 -3.72 -0.69] | True: 0.03 | Pred: 0.19
# Sample 42: [-6.78 -6.86 -5.83] | True: -5.83 | Pred: 0.00
# Sample 43: [-3.42 -7.89  8.38] | True: 8.38 | Pred: 7.76
# Sample 44: [-1.98  8.6   3.12] | True: 8.60 | Pred: 8.03
# Sample 45: [-8.47  6.92 -2.75] | True: 6.92 | Pred: 7.00
# Sample 46: [-3.83 -8.3  -9.94] | True: -3.83 | Pred: 0.00
# Sample 47: [ 2.86 -2.18  3.89] | True: 3.89 | Pred: 4.60
# Sample 48: [-8.21  7.42 -7.34] | True: 7.42 | Pred: 6.71
# Sample 49: [-1.73  2.09  5.16] | True: 5.16 | Pred: 5.34
# Sample 50: [ 8.07  9.11 -7.93] | True: 9.11 | Pred: 10.79
# Sample 51: [ 2.52 -4.3  -1.1 ] | True: 2.52 | Pred: 2.17
# Sample 52: [-7.48  9.11 -7.34] | True: 9.11 | Pred: 8.33
# Sample 53: [5.34 3.51 3.25] | True: 5.34 | Pred: 6.80
# Sample 54: [-5.41  9.09  2.2 ] | True: 9.09 | Pred: 8.66
# Sample 55: [ 1.29 -8.81  4.2 ] | True: 4.20 | Pred: 4.52
# Sample 56: [-1.5  -4.58  8.59] | True: 8.59 | Pred: 8.52
# Sample 57: [ 2.23 -5.53 -5.06] | True: 2.23 | Pred: 2.23
# Sample 58: [-0.48  5.58 -2.56] | True: 5.58 | Pred: 5.04
# Sample 59: [-5.71 -3.42 -7.47] | True: -3.42 | Pred: 0.00
# Sample 60: [ 3.57  7.74 -9.41] | True: 7.74 | Pred: 8.35
# Sample 61: [2.32 5.17 1.81] | True: 5.17 | Pred: 5.23
# Sample 62: [-3.56  5.22  5.26] | True: 5.26 | Pred: 6.22
# Sample 63: [ 3.74 -1.76 -2.65] | True: 3.74 | Pred: 3.37
# Sample 64: [ 1.07 -1.77 -2.98] | True: 1.07 | Pred: 0.97
# Sample 65: [ 6.39  8.59 -0.99] | True: 8.59 | Pred: 9.11
# Sample 66: [-2.24  0.15 -0.6 ] | True: 0.15 | Pred: 0.12
# Sample 67: [ 2.4   2.8  -9.08] | True: 2.80 | Pred: 4.57
# Sample 68: [-3.69  8.42  3.9 ] | True: 8.42 | Pred: 8.20
# Sample 69: [-0.5  -6.03 -6.12] | True: -0.50 | Pred: 0.00
# Sample 70: [-8.96 -3.26  3.38] | True: 3.38 | Pred: 3.01
# Sample 71: [ 6.38  4.62 -8.84] | True: 6.38 | Pred: 7.50
# Sample 72: [-6.01 -1.58  9.67] | True: 9.67 | Pred: 9.12
# Sample 73: [ 1.45 -2.59  4.14] | True: 4.14 | Pred: 4.64
# Sample 74: [-3.81 -6.47  7.3 ] | True: 7.30 | Pred: 7.01
# Sample 75: [-4.55 -2.   -9.95] | True: -2.00 | Pred: 0.00
# Sample 76: [6.69 7.58 3.64] | True: 7.58 | Pred: 8.02
# Sample 77: [-6.97 -9.87 -8.12] | True: -6.97 | Pred: 0.00
# Sample 78: [7.46 4.8  8.42] | True: 8.42 | Pred: 8.32
# Sample 79: [ 5.24  2.53 -0.1 ] | True: 5.24 | Pred: 5.03
# Sample 80: [-7.61 -8.57 -9.35] | True: -7.61 | Pred: 0.00
# Sample 81: [ 4.09 -4.91 -2.01] | True: 4.09 | Pred: 3.68
# Sample 82: [-5.76 -1.82 -7.04] | True: -1.82 | Pred: 0.00
# Sample 83: [-6.53  3.32 -2.97] | True: 3.32 | Pred: 3.22
# Sample 84: [ 6.17 -3.21 -7.34] | True: 6.17 | Pred: 5.96
# Sample 85: [-1.76 -4.85 -3.06] | True: -1.76 | Pred: 0.00
# Sample 86: [-9.52  5.59 -6.96] | True: 5.59 | Pred: 5.06
# Sample 87: [5.03 4.54 7.14] | True: 7.14 | Pred: 7.57
# Sample 88: [-7.67  7.19 -4.73] | True: 7.19 | Pred: 6.62
# Sample 89: [ 3.71  9.39 -1.41] | True: 9.39 | Pred: 9.28
# Sample 90: [-0.08 -2.3  -8.35] | True: -0.08 | Pred: 0.35
# Sample 91: [ 4.8  -9.93  6.21] | True: 6.21 | Pred: 7.33
# Sample 92: [ 7.48  9.46 -2.36] | True: 9.46 | Pred: 10.20
# Sample 93: [-8.22  2.25  5.52] | True: 5.52 | Pred: 6.50
# Sample 94: [-9.95 -2.27 -5.99] | True: -2.27 | Pred: 0.00
# Sample 95: [-0.87 -4.92 -4.09] | True: -0.87 | Pred: 0.00
# Sample 96: [-3.17 -9.5   8.21] | True: 8.21 | Pred: 7.31
# Sample 97: [ 8.38 -1.57 -1.14] | True: 8.38 | Pred: 7.72
# Sample 98: [-4.08 -9.03 -9.73] | True: -4.08 | Pred: 0.00
# Sample 99: [ 3.72 -5.49 -6.43] | True: 3.72 | Pred: 3.69
# Sample 100: [-0.78 -3.33 -3.24] | True: -0.78 | Pred: 0.00
#
# Mean Absolute Error: 0.7533

# %%
import numpy as np
model_params = np.concatenate([
    param.data.numpy().flatten()
    for param in best_model.parameters()
])
np.save('training_weights_max.npy', model_params)

print("Model saved with parameter shape:", model_params.shape)
print("parameters:", model_params)
# Out:
# Model saved with parameter shape: (36,)
# parameters: [ 4.4049355e-01 -6.5013868e-01  3.0294535e-01  3.6545977e-01
#   3.3440459e-01  7.5898433e-01 -4.0414715e-01  3.0438313e-01
#   2.6072821e-01  1.9825459e-01 -1.5431918e-01  2.5659138e-01
#   3.4796780e-01  6.4997572e-01 -7.2413361e-01  9.2074698e-01
#   2.9571498e-02 -1.0623845e+00 -1.7886111e-04 -3.2406163e-01
#  -3.5750297e-01  1.5024623e+00 -8.5184610e-01  1.3564979e+00
#  -1.9338031e+00  1.3171875e+00  6.4054996e-01  2.2628241e+00
#   9.8576146e-01  3.0255020e-01  9.8096597e-01 -7.6458836e-01
#   4.9079806e-01  3.2921913e-01 -9.2270833e-01 -5.0378942e-01]
